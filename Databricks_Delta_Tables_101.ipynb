# %% [markdown]
# # 🧠 Databricks Delta Tables 101 (Managed Tables Only)
# End-to-end learning notebook for Delta Tables: ACID operations, Time Travel, CDC, and Streaming with checkpoints.

# %%
# %sql
CREATE CATALOG IF NOT EXISTS demo;
USE CATALOG demo;
CREATE SCHEMA IF NOT EXISTS delta101;
USE demo.delta101;

# %%
# %sql
CREATE OR REPLACE TABLE sales_delta (
  id BIGINT,
  ts TIMESTAMP,
  product STRING,
  qty INT,
  price DECIMAL(10,2)
) USING DELTA;

INSERT INTO sales_delta VALUES
  (1, current_timestamp(), 'Pencil', 5, 1.20),
  (2, current_timestamp(), 'Pen', 2, 2.50),
  (3, current_timestamp(), 'Notebook', 1, 4.90);

SELECT * FROM sales_delta ORDER BY id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>ts</th><th>product</th><th>qty</th><th>price</th></tr></thead><tbody><tr><td>1</td><td>2025-10-27T04:20:10.817Z</td><td>Pencil</td><td>5</td><td>1.20</td></tr><tr><td>2</td><td>2025-10-27T04:20:10.817Z</td><td>Pen</td><td>2</td><td>2.50</td></tr><tr><td>3</td><td>2025-10-27T04:20:10.817Z</td><td>Notebook</td><td>1</td><td>4.90</td></tr></tbody></table></div>

# %%
# %sql
UPDATE sales_delta SET qty = 10 WHERE id = 1;
DELETE FROM sales_delta WHERE product = 'Pen';
MERGE INTO sales_delta t
USING (SELECT 2 AS id, current_timestamp() AS ts, 'Pen' AS product, 3 AS qty, 2.50 AS price) s
ON t.id = s.id
WHEN MATCHED THEN UPDATE SET *
WHEN NOT MATCHED THEN INSERT *;

SELECT * FROM sales_delta ORDER BY id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>ts</th><th>product</th><th>qty</th><th>price</th></tr></thead><tbody><tr><td>1</td><td>2025-10-27T04:20:10.817Z</td><td>Pencil</td><td>10</td><td>1.20</td></tr><tr><td>2</td><td>2025-10-27T04:22:02.955Z</td><td>Pen</td><td>3</td><td>2.50</td></tr><tr><td>3</td><td>2025-10-27T04:20:10.817Z</td><td>Notebook</td><td>1</td><td>4.90</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE HISTORY sales_delta;
SELECT * FROM sales_delta VERSION AS OF 0;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>9</td><td>2025-10-27T04:09:46.000Z</td><td>73874938602462</td><td>rajendravechalapu@gmail.com</td><td>RESTORE</td><td>Map(version -> 0, timestamp -> null)</td><td>null</td><td>List(546745205863369)</td><td>1027-035855-z3gfqxmp-v2n</td><td>8</td><td>Serializable</td><td>false</td><td>Map(numRestoredFiles -> 0, removedFilesSize -> 3636, numRemovedFiles -> 2, restoredFilesSize -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numOfFilesAfterRestore -> 0, tableSizeAfterRestore -> 0)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>8</td><td>2025-10-27T04:07:39.000Z</td><td>73874938602462</td><td>rajendravechalapu@gmail.com</td><td>MERGE</td><td>Map(predicate -> ["(id#12861L = cast(id#12851 as bigint))"], clusterBy -> [], matchedPredicates -> [{"actionType":"update"}], statsOnLoad -> true, notMatchedBySourcePredicates -> [], notMatchedPredicates -> [{"actionType":"insert"}])</td><td>null</td><td>List(546745205863369)</td><td>1027-035855-z3gfqxmp-v2n</td><td>7</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 1, numTargetBytesAdded -> 1380, numTargetBytesRemoved -> 0, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 0, executionTimeMs -> 2237, materializeSourceTimeMs -> 3, numTargetRowsInserted -> 1, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 945, numTargetRowsUpdated -> 0, numOutputRows -> 1, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 1, numTargetFilesRemoved -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 1182)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>7</td><td>2025-10-27T04:07:02.000Z</td><td>73874938602462</td><td>rajendravechalapu@gmail.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> true, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(546745205863369)</td><td>1027-035855-z3gfqxmp-v2n</td><td>6</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 2301, p25FileSize -> 2256, numDeletionVectorsRemoved -> 1, minFileSize -> 2256, numAddedFiles -> 1, maxFileSize -> 2256, p75FileSize -> 2256, p50FileSize -> 2256, numAddedBytes -> 2256)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>6</td><td>2025-10-27T04:06:59.000Z</td><td>73874938602462</td><td>rajendravechalapu@gmail.com</td><td>DELETE</td><td>Map(predicate -> ["(product#12474 = Pen)"])</td><td>null</td><td>List(546745205863369)</td><td>1027-035855-z3gfqxmp-v2n</td><td>5</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 1625, numDeletionVectorsUpdated -> 0, numDeletedRows -> 1, scanTimeMs -> 1104, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 520)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>5</td><td>2025-10-27T04:06:21.000Z</td><td>73874938602462</td><td>rajendravechalapu@gmail.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> true, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(546745205863369)</td><td>1027-035855-z3gfqxmp-v2n</td><td>4</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 2, numRemovedBytes -> 4449, p ...

# %%
# %sql
-- Add a new column 'channel' of type STRING to the sales_delta table
ALTER TABLE sales_delta ADD COLUMN channel STRING;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-5448948360445371>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', "-- Add a new column 'channel' of type STRING to the sales_delta table\nALTER TABLE sales_delta ADD COLUMN channel STRING;\n\n-- Add a table constraint to ensure 'qty' is always positive\nALTER TABLE sales_delta ADD CONSTRAINT qty_positive CHECK (qty > 0);\n\n-- Show detailed metadata information about the sales_delta table\nDESCRIBE DETAIL sales_delta;\n")
#
# File /databricks/python/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:152, in SqlMagic.sql(self, line, cell)
#     148     raise Exception(
#     149         "Cannot run %sql command because spark connect initialization failed and no stacktrace was available."
#     150     )
#     151 if self.use_py4j:
# --> 152     return self.execute_via_py4j(cell)
#     154 return self.execute_via_sql_comm_handler(cell)
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:237, in SqlMagic.execute_via_py4j(self, cell)
#     234 except BaseException as e:
#     235     self.driver_activity_logger.logExecuteCommandEvent("SQL_MAGIC_PY4J_FAILED",
#     236                                                        json.dumps(get_debug_info(e)))
# --> 237     raise e
#     238 self.driver_activity_logger.logExecuteCommandEvent("SQL_MAGIC_PY4J_SUCCEEDED")
#     239 return result
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:233, in SqlMagic.execute_via_py4j(self, cell)
#     231         print(f"Executing subquery: {query_text}.", file=sys.__stdout__)  # type: ignore
#     232         sql_directive = self.entry_point.getSqlDirective(query_text)
# --> 233         result = self.handle_sql_directive(sql_directive, i == number_of_sub_queries - 1)
#     234 except BaseException as e:
#     235     self.driver_activity_logger.logExecuteCommandEvent("SQL_MAGIC_PY4J_FAILED",
#     236                                                        json.dumps(get_debug_info(e)))
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:257, in SqlMagic.handle_sql_directive(self, sql_directive, is_last_query)
#     254 query = sql_directive.sql()
#     255 self._register_udf_if_needed(
#     256     query, self.entry_point.escapeWidgetValues(self.dbutils.widgets.getAll()))
# --> 257 df = self.get_query_request_result(query)
#     258 if df is None or len(df.schema) == 0:
#     259     # E.g. "create or replace temp view abc as select 1" gets us here and we should not return a result in this case.
#     260     return None
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:129, in SqlMagic.get_query_request_result(self, query)
#     127 if len(widget_bindings := self.dbutils.widgets.getAll()) > 0:
#     128     self.driver_activity_logger.logExecuteCommandEvent("PARAM_SYNTAX_USAGE")
# --> 129 df = self.asserting_spark.sql(query, widget_bindings)
#     130 return df
#
# File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/session.py:736, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#     733         _views.append(SubqueryAlias(df._plan, name))
#     735 cmd = SQL(sqlQuery, _args, _named_args, _views)
# --> 736 data, properties, ei = self.client.execute_command(cmd.command(self._client))
#     737 if "sql_command_result" in properties:
#     738     df = DataFrame(CachedRelation(properties["sql_command_result"]), self)
#
# File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:1306, in SparkConnectClient.execute_command(self, command, observations, extra_request_metadata)
#    1304     req.user_context.user_id = self._user_id
#    1305 req.plan.command.CopyFrom(command)
# -> 1306 data, _, metrics, observed_metrics, properties = self._execute_and_fetch(
#    1307     req, observations or {}, extra_request_metadata
#    1308 )
#    1309 # Create a query execution object.
#    1310 ei = ExecutionInfo(metrics, observed_metrics)
#
# File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:1764, in SparkConnectClient._execute_and_fetch(self, req, observations, extra_request_metadata, self_destruct)
#    1761 properties: Dict[str, Any] = {}
#    1763 with Progress(handlers=self._progress_handlers, operation_id=req.operation_id) as progress:
# -> 1764     for response in self._execute_and_fetch_as_iterator(
#    1765         req, observations, extra_request_metadata or [], progress=progress
#    1766     ):
#    1767         if isinstance(response, StructType):
#    1768             schema = response
#
# File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:1740, in SparkConnectClient._execute_and_fetch_as_iterator(self, req, observations, extra_request_metadata, progress)
#    1738     raise kb
#    1739 except Exception as error:
# -> 1740     self._handle_error(error)
#
# File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:2056, in SparkConnectClient._handle_error(self, error)
#    2054 self.thread_local.inside_error_handling = True
#    2055 if isinstance(error, grpc.RpcError):
# -> 2056     self._handle_rpc_error(error)
#    2057 elif isinstance(error, ValueError):
#    2058     if "Cannot invoke RPC" in str(error) and "closed" in str(error):
#
# File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:2137, in SparkConnectClient._handle_rpc_error(self, rpc_error)
#    2133             d.Unpack(info)
#    2135             self._handle_rpc_error_with_error_info(info, status.message, status_code)  # EDGE
# -> 2137             raise convert_exception(
#    2138                 info,
#    2139                 status.message,
#    2140                 self._fetch_enriched_error(info),
#    2141                 self._display_server_stack_trace(),
#    2142             ) from None
#    2144     raise SparkConnectGrpcException(
#    2145         message=status.message,
#    2146         sql_state=ErrorCode.CLIENT_UNEXPECTED_MISSING_SQL_STATE,  # EDGE
#    2147     ) from None
#    2148 else:
#
# AnalysisException: [FIELD_ALREADY_EXISTS] Cannot add column, because `channel` already exists in "STRUCT<id: BIGINT, ts: TIMESTAMP, product: STRING, qty: INT, price: DECIMAL(10,2), channel: STRING>". SQLSTATE: 42710; line 2 pos 0;
# AddColumns [QualifiedColType(None,channel,StringType,true,None,None,None,None)]
# +- ResolvedTable com.databricks.sql.managedcatalog.UnityCatalogV2Proxy@39ffb085, default.sales_delta, DeltaTableV2(org.apache.spark.sql.classic.SparkSession@75df44ef,s3://dbstorage-prod-c58hg/uc/9c57e47e-c28e-4d0d-93ff-d94e2b5ae47a/44197c2c-845e-4478-9dc0-953bb6f62925/__unitystorage/catalogs/8a6fac30-b4ed-4bb0-8b16-6d1f6a290f34/tables/c0a716bf-d193-4f7b-a171-43a94337a6f9,Some(CatalogTable(
# Catalog: workspace
# Database: default
# Table: sales_delta
# Owner: rajendravechalapu@gmail.com
# Created Time: Mon Oct 27 03:59:14 UTC 2025
# Last Access: UNKNOWN
# Created By: Spark
# Type: MANAGED
# Provider: delta
# Table Properties: [delta.enableDeletionVectors=true, delta.enableRowTracking=true, delta.feature.appendOnly=supported, delta.feature.deletionVectors=supported, delta.feature.domainMetadata=supported, delta.feature.invariants=supported, delta.feature.rowTracking=supported, delta.lastCommitTimestamp=1761539060000, delta.lastUpdateVersion=10, delta.minReaderVersion=3, delta.minWriterVersion=7, delta.rowTracking.materializedRowCommitVersionColumnName=_row-commit-version-col-2d94d1fa-0a8c-4960-9037-c49ea55c2b12, delta.rowTracking.materializedRowIdColumnName=_row-id-col-4875d927-75c6-4590-9820-d86b27e25dbd]
# Statistics: 2866 bytes, 4 rows
# Location: s3://dbstorage-prod-c58hg/uc/9c57e47e-c28e-4d0d-93ff-d94e2b5ae47a/44197c2c-845e-4478-9dc0-953bb6f62925/__unitystorage/catalogs/8a6fac30-b4ed-4bb0-8b16-6d1f6a290f34/tables/c0a716bf-d193-4f7b-a171-43a94337a6f9
# Partition Provider: Catalog
# Schema: root
#  |-- id: long (nullable = true)
#  |-- ts: timestamp (nullable = true)
#  |-- product: string (nullable = true)
#  |-- qty: integer (nullable = true)
#  |-- price: decimal(10,2) (nullable = true)
#  |-- channel: string (nullable = true)
#
# Predictive Optimization: ENABLE (inherited from METASTORE metastore_aws_us_east_2))),Some(workspace.default.sales_delta),None,Map()), [id#16304L, ts#16305, product#16306, qty#16307, price#16308, channel#16309]
#
#
# JVM stacktrace:
# org.apache.spark.sql.catalyst.ExtendedAnalysisException
# 	at org.apache.spark.sql.catalyst.analysis.package$AnalysisErrorAt.failAnalysis(package.scala:55)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkColumnNotExists$1(CheckAnalysis.scala:1138)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAlterTableCommand$3(CheckAnalysis.scala:1157)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAlterTableCommand$3$adapted(CheckAnalysis.scala:1156)
# 	at scala.collection.immutable.List.foreach(List.scala:334)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAlterTableCommand(CheckAnalysis.scala:1156)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$2(CheckAnalysis.scala:842)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis0$2$adapted(CheckAnalysis.scala:324)
# 	at org.apache.spark.sql.catalyst.trees.TreeNode.foreachUp(TreeNode.scala:312)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis0(CheckAnalysis.scala:324)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis0$(CheckAnalysis.scala:295)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis0(Analyzer.scala:579)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.$anonfun$checkAnalysis$1(CheckAnalysis.scala:280)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:200)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis(CheckAnalysis.scala:266)
# 	at org.apache.spark.sql.catalyst.analysis.CheckAnalysis.checkAnalysis$(CheckAnalysis.scala:262)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.checkAnalysis(Analyzer.scala:579)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.$anonfun$resolveInFixedPoint$1(HybridAnalyzer.scala:413)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:267)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.resolveInFixedPoint(HybridAnalyzer.scala:413)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.$anonfun$apply$1(HybridAnalyzer.scala:99)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.withTrackedAnalyzerBridgeState(HybridAnalyzer.scala:136)
# 	at org.apache.spark.sql.catalyst.analysis.resolver.HybridAnalyzer.apply(HybridAnalyzer.scala:92)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$2(Analyzer.scala:636)
# 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.markInAnalyzer(AnalysisHelper.scala:425)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$1(Analyzer.scala:636)
# 	at com.databricks.sql.unity.SAMSnapshotHelper$.visitPlansDuringAnalysis(SAMSnapshotHelper.scala:41)
# 	at org.apache.spark.sql.catalyst.analysis.Analyzer.executeAndCheck(Analyzer.scala:628)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$3(QueryExecution.scala:347)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:200)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.catalyst.QueryPlanningTracker.measurePhase(QueryPlanningTracker.scala:675)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$8(QueryExecution.scala:832)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withExecutionPhase$1(SQLExecution.scala:157)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:328)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:324)
# 	at com.databricks.util.TracingSpanUtils$.$anonfun$withTracing$4(TracingSpanUtils.scala:235)
# 	at com.databricks.util.TracingSpanUtils$.withTracing(TracingSpanUtils.scala:129)
# 	at com.databricks.util.TracingSpanUtils$.withTracing(TracingSpanUtils.scala:233)
# 	at com.databricks.tracing.TracingUtils$.withTracing(TracingUtils.scala:296)
# 	at com.databricks.spark.util.DatabricksTracingHelper.withSpan(DatabricksSparkTracingHelper.scala:115)
# 	at com.databricks.spark.util.DBRTracing$.withSpan(DBRTracing.scala:47)
# 	at org.apache.spark.sql.execution.SQLExecution$.withExecutionPhase(SQLExecution.scala:138)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$7(QueryExecution.scala:832)
# 	at org.apache.spark.sql.execution.QueryExecution$.withInternalError(QueryExecution.scala:1478)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$5(QueryExecution.scala:825)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$4(QueryExecution.scala:822)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$3(QueryExecution.scala:822)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$2(QueryExecution.scala:821)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.withQueryExecutionId(QueryExecution.scala:809)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$1(QueryExecution.scala:820)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:860)
# 	at org.apache.spark.sql.execution.QueryExecution.executePhase(QueryExecution.scala:819)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$2(QueryExecution.scala:329)
# 	at com.databricks.sql.util.MemoryTrackerHelper.withMemoryTracking(MemoryTrackerHelper.scala:111)
# 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyAnalyzed$1(QueryExecution.scala:328)
# 	at scala.util.Try$.apply(Try.scala:217)
# 	at org.apache.spark.util.Utils$.doTryWithCallerStacktrace(Utils.scala:1687)
# 	at org.apache.spark.util.LazyTry.tryT$lzycompute(LazyTry.scala:60)
# 	at org.apache.spark.util.LazyTry.tryT(LazyTry.scala:59)
# 	at org.apache.spark.util.LazyTry.get(LazyTry.scala:75)
# 	at org.apache.spark.sql.execution.QueryExecution.analyzed(QueryExecution.scala:389)
# 	at org.apache.spark.sql.execution.QueryExecution.assertAnalyzed(QueryExecution.scala:302)
# 	at org.apache.spark.sql.classic.Dataset$.$anonfun$ofRows$3(Dataset.scala:154)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:860)
# 	at org.apache.spark.sql.classic.SparkSession.$anonfun$withActiveAndFrameProfiler$1(SparkSession.scala:1077)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:200)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.classic.SparkSession.withActiveAndFrameProfiler(SparkSession.scala:1077)
# 	at org.apache.spark.sql.classic.Dataset$.ofRows(Dataset.scala:146)
# 	at org.apache.spark.sql.classic.SparkSession.$anonfun$sql$5(SparkSession.scala:856)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:860)
# 	at org.apache.spark.sql.classic.SparkSession.sql(SparkSession.scala:819)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.executeSQL(SparkConnectPlanner.scala:3554)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.handleSqlCommand(SparkConnectPlanner.scala:3378)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.process(SparkConnectPlanner.scala:3255)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.handleCommand(ExecuteThreadRunner.scala:383)
# 	at org.apache.spark.util.Utils$.getTryWithCallerStacktrace(Utils.scala:1748)
# 	at org.apache.spark.util.LazyTry.get(LazyTry.scala:75)
# 	at org.apache.spark.sql.execution.QueryExecution.executedPlan(QueryExecution.scala:753)
# 	at com.databricks.spark.sqlgateway.history.SqlExecutionMetrics.$anonfun$setQueryExecution$1(SqlExecutionMetrics.scala:186)
# 	at scala.Option.flatMap(Option.scala:283)
# 	at com.databricks.spark.sqlgateway.history.SqlExecutionMetrics.setQueryExecution(SqlExecutionMetrics.scala:186)
# 	at com.databricks.spark.sqlgateway.history.SqlGatewayHistorySparkListener.$anonfun$onSqlStart$1(SqlGatewayHistorySparkListener.scala:832)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:200)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at com.databricks.spark.sqlgateway.history.SqlGatewayHistorySparkListener.com$databricks$spark$sqlgateway$history$SqlGatewayHistorySparkListener$$onSqlStart(SqlGatewayHistorySparkListener.scala:779)
# 	at com.databricks.spark.sqlgateway.history.SqlGatewayHistorySparkListener$$anonfun$onOtherEventDefault$1.applyOrElse(SqlGatewayHistorySparkListener.scala:249)
# 	at com.databricks.spark.sqlgateway.history.SqlGatewayHistorySparkListener$$anonfun$onOtherEventDefault$1.applyOrElse(SqlGatewayHistorySparkListener.scala:237)
# 	at scala.runtime.AbstractPartialFunction.apply(AbstractPartialFunction.scala:35)
# 	at com.databricks.spark.sqlgateway.history.utils.ScriptStatementHelper$$anonfun$onOtherEvent$1.applyOrElse(ScriptStatementHelper.scala:29)
# 	at com.databricks.spark.sqlgateway.history.utils.ScriptStatementHelper$$anonfun$onOtherEvent$1.applyOrElse(ScriptStatementHelper.scala:29)
# 	at scala.PartialFunction$OrElse.applyOrElse(PartialFunction.scala:270)
# 	at com.databricks.spark.sqlgateway.history.SqlGatewayHistorySparkListener.$anonfun$onOtherEvent$1(SqlGatewayHistorySparkListener.scala:215)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:200)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at com.databricks.spark.sqlgateway.history.SqlGatewayHistorySparkListener.onOtherEvent(SqlGatewayHistorySparkListener.scala:215)
# 	at org.apache.spark.scheduler.SparkListenerBus.doPostEvent(SparkListenerBus.scala:108)
# 	at org.apache.spark.scheduler.SparkListenerBus.doPostEvent$(SparkListenerBus.scala:28)
# 	at org.apache.spark.scheduler.AsyncEventQueue.doPostEvent(AsyncEventQueue.scala:46)
# 	at org.apache.spark.scheduler.AsyncEventQueue.doPostEvent(AsyncEventQueue.scala:46)
# 	at org.apache.spark.util.ListenerBus.postToAll(ListenerBus.scala:208)
# 	at org.apache.spark.util.ListenerBus.postToAll$(ListenerBus.scala:172)
# 	at org.apache.spark.scheduler.AsyncEventQueue.super$postToAll(AsyncEventQueue.scala:130)
# 	at org.apache.spark.scheduler.AsyncEventQueue.$anonfun$dispatch$1(AsyncEventQueue.scala:130)
# 	at scala.runtime.java8.JFunction0$mcJ$sp.apply(JFunction0$mcJ$sp.scala:17)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:59)
# 	at org.apache.spark.scheduler.AsyncEventQueue.org$apache$spark$scheduler$AsyncEventQueue$$dispatch(AsyncEventQueue.scala:116)
# 	at org.apache.spark.scheduler.AsyncEventQueue$$anon$2.$anonfun$run$1(AsyncEventQueue.scala:112)
# 	at org.apache.spark.util.Utils$.tryOrStopSparkContext(Utils.scala:1575)
# 	at org.apache.spark.scheduler.AsyncEventQueue$$anon$2.run(AsyncEventQueue.scala:112)

# %%
# %sql
-- Add a table constraint to ensure 'qty' is always positive
ALTER TABLE sales_delta ADD CONSTRAINT qty_positive CHECK (qty > 0);

-- Show detailed metadata information about the sales_delta table
DESCRIBE DETAIL sales_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>clusteringColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th><th>statistics</th><th>clusterByAuto</th></tr></thead><tbody><tr><td>delta</td><td>43313070-7996-4e48-84c7-4f21b250dfda</td><td>workspace.default.sales_delta</td><td>null</td><td></td><td>2025-10-27T03:59:12.857Z</td><td>2025-10-27T04:25:35.000Z</td><td>List()</td><td>List()</td><td>0</td><td>0</td><td>Map(delta.enableDeletionVectors -> true, delta.enableRowTracking -> true, delta.constraints.qty_positive -> qty > 0, delta.rowTracking.materializedRowCommitVersionColumnName -> _row-commit-version-col-2d94d1fa-0a8c-4960-9037-c49ea55c2b12, delta.rowTracking.materializedRowIdColumnName -> _row-id-col-4875d927-75c6-4590-9820-d86b27e25dbd)</td><td>3</td><td>7</td><td>List(appendOnly, checkConstraints, deletionVectors, domainMetadata, invariants, rowTracking)</td><td>Map(numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0)</td><td>false</td></tr></tbody></table></div>

# %%
# Import functions from pyspark.sql as F
from pyspark.sql import functions as F

# Read the 'sales_delta' table and add a new column 'channel' with value 'web'
df = spark.table('demo.delta101.sales_delta').withColumn('channel', F.lit('web'))

# Write the DataFrame back to the same Delta table, allowing schema evolution (mergeSchema)
(df.write
  .option('mergeSchema','true')  # Allow new columns to be added to the table schema
  .format('delta')               # Use Delta Lake format
  .mode('append')                # Append new data to the table
  .saveAsTable('demo.delta101.sales_delta'))  # Save to the specified table

# %%
display(spark.table('demo.delta101.sales_delta'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>ts</th><th>product</th><th>qty</th><th>price</th><th>channel</th></tr></thead><tbody><tr><td>3</td><td>2025-10-27T04:20:10.817Z</td><td>Notebook</td><td>1</td><td>4.90</td><td>null</td></tr><tr><td>1</td><td>2025-10-27T04:20:10.817Z</td><td>Pencil</td><td>10</td><td>1.20</td><td>null</td></tr><tr><td>3</td><td>2025-10-27T04:20:10.817Z</td><td>Notebook</td><td>1</td><td>4.90</td><td>web</td></tr><tr><td>1</td><td>2025-10-27T04:20:10.817Z</td><td>Pencil</td><td>10</td><td>1.20</td><td>web</td></tr><tr><td>2</td><td>2025-10-27T04:22:02.955Z</td><td>Pen</td><td>3</td><td>2.50</td><td>web</td></tr><tr><td>2</td><td>2025-10-27T04:22:02.955Z</td><td>Pen</td><td>3</td><td>2.50</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
-- OPTIMIZE compacts small files in the Delta table to improve read performance
OPTIMIZE sales_delta;

-- OPTIMIZE ... ZORDER BY physically sorts data by specified columns to speed up queries on those columns
OPTIMIZE sales_delta ZORDER BY (product, ts);

-- VACUUM removes old files no longer needed by the Delta table, retaining files from the last 168 hours
VACUUM sales_delta RETAIN 168 HOURS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td></td></tr></tbody></table></div>

# %%
# %sql
-- Enable Change Data Feed (CDF) on the sales_delta table to track row-level changes
ALTER TABLE sales_delta SET TBLPROPERTIES ('delta.enableChangeDataFeed' = 'true');

# %%
# %sql
-- record max/latest version of the table to use in CDC later

DESCRIBE HISTORY sales_delta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>17</td><td>2025-10-27T04:33:53.000Z</td><td>73874938602462</td><td>rajendravechalapu@gmail.com</td><td>UPDATE</td><td>Map(predicate -> ["(product#18862 = Pencil)"])</td><td>null</td><td>List(529636418100290)</td><td>1027-035855-z3gfqxmp-v2n</td><td>16</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 159, numDeletionVectorsUpdated -> 0, scanTimeMs -> 159, numAddedFiles -> 0, numUpdatedRows -> 0, numAddedBytes -> 0, rewriteTimeMs -> 0)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>16</td><td>2025-10-27T04:33:42.000Z</td><td>73874938602462</td><td>rajendravechalapu@gmail.com</td><td>SET TBLPROPERTIES</td><td>Map(properties -> {"delta.enableChangeDataFeed":"true"})</td><td>null</td><td>List(529636418100290)</td><td>1027-035855-z3gfqxmp-v2n</td><td>15</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>15</td><td>2025-10-27T04:32:38.000Z</td><td>73874938602462</td><td>rajendravechalapu@gmail.com</td><td>UPDATE</td><td>Map(predicate -> ["(product#18634 = Pencil)"])</td><td>null</td><td>List(529636418100290)</td><td>1027-035855-z3gfqxmp-v2n</td><td>14</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 183, numDeletionVectorsUpdated -> 0, scanTimeMs -> 181, numAddedFiles -> 0, numUpdatedRows -> 0, numAddedBytes -> 0, rewriteTimeMs -> 0)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>14</td><td>2025-10-27T04:32:36.000Z</td><td>73874938602462</td><td>rajendravechalapu@gmail.com</td><td>SET TBLPROPERTIES</td><td>Map(properties -> {"delta.enableChangeDataFeed":"true"})</td><td>null</td><td>List(529636418100290)</td><td>1027-035855-z3gfqxmp-v2n</td><td>13</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>13</td><td>2025-10-27T04:31:30.000Z</td><td>73874938602462</td><td>rajendravechalapu@gmail.com</td><td>VACUUM END</td><td>Map(status -> COMPLETED)</td><td>null</td><td>List(529636418100290)</td><td>1027-035855-z3gfqxmp-v2n</td><td>12</td><td>SnapshotIsolation</td><td>true</td><td>Map(numDeletedFiles -> 0, numVacuumedDirectories -> 1)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>12</td><td>2025-10-27T04:31:29.000Z</td><td>73874938602462</td><td>rajendravechalapu@gmail.com</td><td>VACUUM START</td><td>Map(retentionCheckEnabled -> true, defaultRetentionMillis -> 604800000, specifiedRetentionMillis -> 604800000)</td><td>null</td><td>List(529636418100290)</td><td>1027-035855-z3gfqxmp-v2n</td><td>11</td><td>SnapshotIsolation</td><td>true</td><td>Map(numFilesToDelete -> 0, sizeOfDataToDelete -> 0)</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>11</td><td>2025-10-27T04:25:35.000Z</td><td>73874938602462</td><td>rajendravechalapu@gmail.com</td><td>ADD CONSTRAINT</td><td>Map(name -> qty_positive, expr -> qty > 0)</td><td>null</td><td>List(529636418100290)</td><td>1027-035855-z3gfqxmp-v2n</td><td>10</td><td>WriteSerializable</td><td>false</td><td>Map()</td><td>null</td><td>Databricks-Runtime/17.2.x-aarch64-photon-scala2.13</td></tr><tr><td>10 ...

# %%
# %sql

-- Increment the 'qty' column by 1 for all rows where the product is 'Pencil'
UPDATE sales_delta SET qty = qty + 1 WHERE product = 'Pencil';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE HISTORY sales_delta;

# %%
# %sql
-- Query the changes (inserts, updates, deletes) in the sales_delta table from version 0 to 100 using Change Data Feed
-- Replace <cdf_enabled_version> with the version number where CDF was enabled
SELECT *
FROM table_changes('sales_delta', 14, 17);
--SELECT * FROM table_changes('sales_delta', 0, 100);
-- SELECT *
-- FROM table_changes('sales_delta', <cdf_enabled_version>, <latest_version>);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>ts</th><th>product</th><th>qty</th><th>price</th><th>channel</th><th>_change_type</th><th>_commit_version</th><th>_commit_timestamp</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Show detailed metadata information about the sales_delta table
DESCRIBE DETAIL sales_delta;

-- Show the last 10 operations in the sales_delta table's history
DESCRIBE HISTORY sales_delta LIMIT 10;

-- Enable automatic file compaction and optimized writes for the sales_delta table
ALTER TABLE sales_delta SET TBLPROPERTIES (
  'delta.autoOptimize.optimizeWrite'='true',
  'delta.autoOptimize.autoCompact'='true'
);
# Out:
#   File <command-5448948360445378>, line 1
#     DESCRIBE HISTORY sales_delta LIMIT 10;
#              ^
# SyntaxError: invalid syntax
